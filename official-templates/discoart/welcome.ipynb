# %% [markdown]
# ## Discoart Support
# <a href="https://pypi.org/project/discoart/"><img src="https://img.shields.io/pypi/v/discoart?style=flat-square&amp;label=Release" alt="PyPI"></a>
# <a href="https://slack.jina.ai"><img src="https://img.shields.io/badge/Slack-3.1k-blueviolet?logo=slack&amp;logoColor=white&style=flat-square"></a>
#
# ## RunPod/Fever Dreams Support
# [![Discord](https://badgen.net/badge/icon/discord?icon=discord&label=RunPod)](https://discord.gg/pJ3P2DbUUq)
# [![Discord](https://badgen.net/badge/icon/discord?icon=discord&label=Fever%20Dreams)](https://discord.gg/Pmy3wFKbna)
# [![Maintenance](https://img.shields.io/badge/Maintained%3F-yes-green.svg)](https://github.com/entmike/docker-images/discoart)
# ![Terminal](https://badgen.net/badge/icon/terminal?icon=terminal&label)
# [![Issues](https://img.shields.io/github/issues/entmike/docker-images)](https://github.com/entmike/docker-images/issues)
# ![Stars](https://img.shields.io/github/stars/entmike/docker-images)
# ![Commits](https://img.shields.io/github/commit-activity/w/entmike/docker-images)
#
# 😎 **If you are already a DD user**: you are ready to go! There is no extra learning, DiscoArt respects the same parameter semantics as DD. So just unleash your creativity! [Read more about DiscoArt vs. DD](https://github.com/jina-ai/discoart/blob/main/FEATURES.md)
#
# You can run the cheatsheet cell below to get some descriptions of the parameters. You can also run `from discoart import cheatsheet; cheatsheet()` in any cell. DiscoArt specific parameters are highlighted in the cheatsheet.
#
# 👶 **If you are a [DALL·E Flow](https://github.com/jina-ai/dalle-flow/) or new user**: you may want to take this step by step, as Disco Diffusion works in a very different way than DALL·E. It is much more advanced and powerful: e.g. Disco Diffusion can take weighted & structured text prompts; it can initialize from a image with controlled noise; and there are way more parameters one can tweak. Impatient prompt like `"armchair avocado"` will give you nothing but confusion and frustration. I highly recommend you to check out the following resources before trying your own prompt:
# - [Zippy's Disco Diffusion Cheatsheet v0.3](https://docs.google.com/document/d/1l8s7uS2dGqjztYSjPpzlmXLjl5PM3IGkRWI3IiCuK7g/mobilebasic)
# - [EZ Charts - Diffusion Parameter Studies](https://docs.google.com/document/d/1ORymHm0Te18qKiHnhcdgGp-WSt8ZkLZvow3raiu2DVU/edit#)
# - [Disco Diffusion 70+ Artist Studies](https://weirdwonderfulai.art/resources/disco-diffusion-70-plus-artist-studies/)
# - [A Traveler’s Guide to the Latent Space](https://sweet-hall-e72.notion.site/A-Traveler-s-Guide-to-the-Latent-Space-85efba7e5e6a40e5bd3cae980f30235f#e122e748b86e4fc0ad6a7a50e46d6e10)
# - [Disco Diffusion Illustrated Settings](https://coar.notion.site/Disco-Diffusion-Illustrated-Settings-cd4badf06e08440c99d8a93d4cd39f51)
# - [Coar’s Disco Diffusion Guide](https://coar.notion.site/coar/Coar-s-Disco-Diffusion-Guide-3d86d652c15d4ca986325e808bde06aa#8a3c6e9e4b6847afa56106eacb6f1f79)
#
# If you want to learn more about what discoart can do, you can check out the examples in the "examples" folder. You can do some really cool stuff!

# %% [markdown]
# ## Start Rendering!

# %%
from discoart import create

da = create(
    batch_size=1,
    n_batches=1,
    text_prompts='A painting of sea cliffs in a tumultuous storm, Trending on ArtStation.',
)
# Out:
# ╔═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# ║                                                👀 Result preview                                                ║
# ╚═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
#
# This preview is NOT in HD. Do NOT use it for your final artworks.
#
# To save the full-size images, please check out the instruction in the next section.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                 discoart-58655f513b9f02dd615adc3ba685d5c2
# ╭─────────────────────────┬─────────────────────────────────────────────────────────────────────────────╮
# │                Argument │ Value                                                                       │
# ├─────────────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │              batch_name │ None                                                                        │
# │              batch_size │ 1                                                                           │
# │              clamp_grad │ True                                                                        │
# │               clamp_max │ 0.05                                                                        │
# │           clip_denoised │ False                                                                       │
# │     clip_guidance_scale │ 5000                                                                        │
# │             clip_models │ ['ViT-B-32::openai', 'ViT-B-16::openai', 'RN50::openai']                    │
# │   clip_models_schedules │ None                                                                        │
# │              cut_ic_pow │ 1.0                                                                         │
# │            cut_icgray_p │ [0.2]*400+[0]*600                                                           │
# │            cut_innercut │ [4]*400+[12]*600                                                            │
# │            cut_overview │ [12]*400+[4]*600                                                            │
# │     cut_schedules_group │ None                                                                        │
# │            cutn_batches │ 4                                                                           │
# │         diffusion_model │ 512x512_diffusion_uncond_finetune_008100                                    │
# │  diffusion_model_config │ None                                                                        │
# │ diffusion_sampling_mode │ ddim                                                                        │
# │            display_rate │ 20                                                                          │
# │                     eta │ 0.8                                                                         │
# │            fuzzy_prompt │ False                                                                       │
# │              init_image │ None                                                                        │
# │              init_scale │ 1000                                                                        │
# │              n_batches* │ 1                                                                           │
# │          name_docarray* │ discoart-58655f513b9f02dd615adc3ba685d5c2                                   │
# │     on_misspelled_token │ ignore                                                                      │
# │             perlin_init │ False                                                                       │
# │             perlin_mode │ mixed                                                                       │
# │                rand_mag │ 0.05                                                                        │
# │         randomize_class │ True                                                                        │
# │             range_scale │ 150                                                                         │
# │               sat_scale │ 0                                                                           │
# │               save_rate │ 20                                                                          │
# │                   seed* │ 3114062142                                                                  │
# │               skip_augs │ False                                                                       │
# │              skip_event │ None                                                                        │
# │              skip_steps │ 0                                                                           │
# │                   steps │ 250                                                                         │
# │              stop_event │ None                                                                        │
# │        text_clip_on_cpu │ False                                                                       │
# │           text_prompts* │ ['A painting of sea cliffs in a tumultuous storm, Trending on ArtStation.'] │
# │  transformation_percent │ [0.09]                                                                      │
# │                tv_scale │ 0                                                                           │
# │ use_horizontal_symmetry │ False                                                                       │
# │     use_secondary_model │ True                                                                        │
# │   use_vertical_symmetry │ False                                                                       │
# │            width_height │ [1280, 768]                                                                 │
# ╰─────────────────────────┴─────────────────────────────────────────────────────────────────────────────╯
#                              showing all args (bold * args are non-default)
# /workspace/discoart-58655f513b9f02dd615adc3ba685d5c2.svg
# /workspace/discoart-58655f513b9f02dd615adc3ba685d5c2.protobuf.lz4
# ╔═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# ║                                                  🖼️ Save images                                                  ║
# ╚═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
#
# Final results and intermediate results are created under the current working directory, e.g.
#
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ ./discoart-58655f513b9f02dd615adc3ba685d5c2/[i]-step-[i].png                                                    │
# │ ./discoart-58655f513b9f02dd615adc3ba685d5c2/[i]-progress.png                                                    │
# │ ./discoart-58655f513b9f02dd615adc3ba685d5c2/[i]-done.png                                                        │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# where:
#
#  • name-docarray is the name of the run, you can specify it otherwise it is a random name.
#  • i-* is up to the value of n_batches.
#  • *-done-* is the final image on done.
#  • *-step-* is the intermediate image at certain step.
#  • *-progress-* is the sprite image of all intermediate results so far.
#
# ╔═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# ║                                            💾 Save & load the batch                                             ║
# ╚═════════════════════════════════════════════════════════════════════════════════════════════════════════════════╝
#
# Results are stored in a ]8;id=804411;https://docarray.jina.ai/fundamentals/documentarray/\DocumentArray]8;;\ available both local and cloud.
#
# You may also download the file manually and load it from local disk:
#
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ da = DocumentArray.load_binary('discoart-58655f513b9f02dd615adc3ba685d5c2.protobuf.lz4')                        │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# You can simply pull it from any machine:
#
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ # pip install docarray[common]                                                                                  │
# │ from docarray import DocumentArray                                                                              │
# │                                                                                                                 │
# │ da = DocumentArray.pull('discoart-58655f513b9f02dd615adc3ba685d5c2')                                            │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# More usage such as plotting, post-analysis can be found in the ]8;id=78954;https://github.com/jina-ai/discoart\README]8;;\.

# %% [markdown]
# ## Configuration Cheat Sheet

# %%
from discoart import cheatsheet

cheatsheet()

# %% [markdown]
# ## Seeing what discoart version you are running

# %%
from discoart import __version__
print(__version__)
# Out:
# 0.7.3

# %% [markdown]
# ## (Optional) Run to make sure you are on the latest and greatest version

# %%
# !pip install discoart --upgrade

# %% [markdown]
# ## Explore!
#
# There are some additional examples included in the `examples` folder in your `/workspace`.  Note that the `examples` folder is a temporary folder that you should not save anything in that you want to keep.  Any other location in `/workspace` is ALL YOURS!
